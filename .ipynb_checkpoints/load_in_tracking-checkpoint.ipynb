# %%
import h5py
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
path = r'C:\Users\matthewp.W221N\Downloads\30.10.19_sp11DLC_resnet50_spider_analysisNov1shuffle1_1030000.h5'

# %%
data = pd.read_hdf(path)

# %%
for key in data:
    print(key)
# Out:
# ('DLC_resnet50_spider_analysisNov1shuffle1_1030000', 'head', 'x')
# ('DLC_resnet50_spider_analysisNov1shuffle1_1030000', 'head', 'y')
# ('DLC_resnet50_spider_analysisNov1shuffle1_1030000', 'head', 'likelihood')
# ('DLC_resnet50_spider_analysisNov1shuffle1_1030000', 'body', 'x')
# ('DLC_resnet50_spider_analysisNov1shuffle1_1030000', 'body', 'y')
# ('DLC_resnet50_spider_analysisNov1shuffle1_1030000', 'body', 'likelihood')
# ('DLC_resnet50_spider_analysisNov1shuffle1_1030000', 'tail', 'x')
# ('DLC_resnet50_spider_analysisNov1shuffle1_1030000', 'tail', 'y')
# ('DLC_resnet50_spider_analysisNov1shuffle1_1030000', 'tail', 'likelihood')
# ('DLC_resnet50_spider_analysisNov1shuffle1_1030000', 'NW', 'x')
# ('DLC_resnet50_spider_analysisNov1shuffle1_1030000', 'NW', 'y')
# ('DLC_resnet50_spider_analysisNov1shuffle1_1030000', 'NW', 'likelihood')
# ('DLC_resnet50_spider_analysisNov1shuffle1_1030000', 'NE', 'x')
# ('DLC_resnet50_spider_analysisNov1shuffle1_1030000', 'NE', 'y')
# ...

# %%
x,y = (data['DLC_resnet50_spider_analysisNov1shuffle1_1030000']['body']['x'], 
       data['DLC_resnet50_spider_analysisNov1shuffle1_1030000']['body']['y'])

head_x, head_y = (data['DLC_resnet50_spider_analysisNov1shuffle1_1030000']['head']['x'], 
       data['DLC_resnet50_spider_analysisNov1shuffle1_1030000']['head']['y'])
tail_x, tail_y = (data['DLC_resnet50_spider_analysisNov1shuffle1_1030000']['tail']['x'], 
       data['DLC_resnet50_spider_analysisNov1shuffle1_1030000']['tail']['y'])

# %%
fig, ax = plt.subplots(figsize=(10,10))

ax.plot(x,y)
ax.plot(head_x, head_y, c='navy')
ax.plot(tail_x, tail_y, c='cyan')
ax.set_ylim(0,1216)
ax.set_xlim(0,1344)
# Out:
# (0, 1344)
