# %%
import h5py
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
import matplotlib.patches as patches
path = r'C:\Users\maksymilianm\Dropbox (UCL - SWC)\Project_spiders\Analysis\shade_arena_exploration\23_01_20_sp8-0DLC_resnet50_large_spidersJan27shuffle1_1030000.h5'

data = pd.read_hdf(path)
#for key in data:
 #   print(key)

centre_x, centre_y = (data['DLC_resnet50_large_spidersJan27shuffle1_1030000']['centre']['x'], 
                   data['DLC_resnet50_large_spidersJan27shuffle1_1030000']['centre']['y'])
head_x, head_y = (data['DLC_resnet50_large_spidersJan27shuffle1_1030000']['head']['x'], 
                   data['DLC_resnet50_large_spidersJan27shuffle1_1030000']['head']['y'])
tail_x, tail_y = (data['DLC_resnet50_large_spidersJan27shuffle1_1030000']['tail']['x'], 
                   data['DLC_resnet50_large_spidersJan27shuffle1_1030000']['tail']['y'])
#AR leg_x, AR leg_y = (data['DLC_resnet50_large_spidersJan27shuffle1_1030000']['AR leg']['x'], 
#             data['DLC_resnet50_large_spidersJan27shuffle1_1030000']['AR leg']['y'])
#AL leg_x, AL leg_y = (data['DLC_resnet50_large_spidersJan27shuffle1_1030000']['AL leg']['x'], 
#            data['DLC_resnet50_large_spidersJan27shuffle1_1030000']['AL leg']['y'])
#PR leg_x, PR leg_y = (data['DLC_resnet50_large_spidersJan27shuffle1_1030000']['PR leg_x']['x'], 
#             data['DLC_resnet50_large_spidersJan27shuffle1_1030000']['PR leg_x']['y'])
#PL leg_x, PL leg_y = (data['DLC_resnet50_large_spidersJan27shuffle1_1030000']['PL leg']['x'], 
#             data['DLC_resnet50_large_spidersJan27shuffle1_1030000']['PL leg']['y'])

def compute_distance(xs,ys):
    
    dx = np.diff(xs, axis=0)
    dy = np.diff(ys, axis=0)
    
    distances = np.hypot(dx,dy)
    
    return distances

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.plot(centre_x, centre_y, c='b')
ax.set_ylim(1152, 0)
ax.set_xlim(0, 1216)
ROI = patches.Rectangle((415,682),435,400,linewidth=3,edgecolor='r',facecolor='none')
ax.add_patch(ROI)
#plt.savefig(r'C:\Users\maksymilianm\Dropbox (UCL - SWC)\Project_spiders\Analysis\\shade_arena_exploration\23_01_20_sp12_trajectory.png')

# %%
fig, ax = plt.subplots(figsize=(12,10))
ax.set_ylim(1152, 0)
ax.set_xlim(0, 1216)
plt.hexbin(centre_x,centre_y, bins = 'log', cmap=plt.cm.jet)
plt.colorbar()
ROI = patches.Rectangle((415,682),435,400,linewidth=3,edgecolor='r',facecolor='none')
ax.add_patch(ROI)
#plt.savefig(r'C:\Users\maksymilianm\Dropbox (UCL - SWC)\Project_spiders\Analysis\\shade_arena_exploration\23_01_20_sp8_hexplot.png')

# %%
import seaborn as sns
fig, ax = plt.subplots(figsize=(10,10))
ax = sns.kdeplot(centre_x, centre_y, cmap='coolwarm', n_levels = 10, shade=True)
ax.set_frame_on(False)
ax.set_ylim(0,1216)
ax.set_xlim(0,1344)
plt.savefig(r'C:\Users\maksymilianm\Dropbox (UCL - SWC)\Project_spiders\Analysis\shade_arena_exploration\24_01_20_sp7_heatmap.png')
plt.show()

# %%
plt.figure(figsize=(12,10))
plt.hist2d(centre_x, centre_y, bins=100, cmin = 1, cmax = 600)
plt.colorbar()
